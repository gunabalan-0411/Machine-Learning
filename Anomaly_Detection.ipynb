# %% [markdown]
# <a href="https://colab.research.google.com/github/gunabalan-0411/Machine-Learning/blob/main/Anomaly_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hellow world")
